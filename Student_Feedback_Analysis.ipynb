# %%
# Importing all the necessary libraries.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.style.use('default')
sns.set()

# %%
# Loading the dataset.

# %%
df = pd.read_csv("D:\Career\Internships\Future Interns\Task 3\Dataset\student_feedback.csv")
df.head()
# Out:
#    Unnamed: 0  Student ID  Well versed with the subject  \
# 0           0         340                             5
# 1           1         253                             6
# 2           2         680                             7
# 3           3         806                             9
# 4           4         632                             8
#
#    Explains concepts in an understandable way  Use of presentations  \
# 0                                           2                     7
# 1                                           5                     8
# 2                                           7                     6
# 3                                           6                     7
# 4                                          10                     8
#
#    Degree of difficulty of assignments  Solves doubts willingly  \
# 0                                    6                        9
# 1                                    6                        2
# ...

# %%
# Understanding the datset structure.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1001 entries, 0 to 1000
# Data columns (total 10 columns):
#  #   Column                                                Non-Null Count  Dtype
# ---  ------                                                --------------  -----
#  0   Unnamed: 0                                            1001 non-null   int64
#  1   Student ID                                            1001 non-null   int64
#  2   Well versed with the subject                          1001 non-null   int64
#  3   Explains concepts in an understandable way            1001 non-null   int64
#  4   Use of presentations                                  1001 non-null   int64
#  5   Degree of difficulty of assignments                   1001 non-null   int64
#  6   Solves doubts willingly                               1001 non-null   int64
#  7   Structuring of the course                             1001 non-null   int64
# ...

# %%
df.describe()
# Out:
#         Unnamed: 0   Student ID  Well versed with the subject  \
# count  1001.000000  1001.000000                   1001.000000
# mean    500.000000   500.000000                      7.497502
# std     289.108111   289.108111                      1.692998
# min       0.000000     0.000000                      5.000000
# 25%     250.000000   250.000000                      6.000000
# 50%     500.000000   500.000000                      8.000000
# 75%     750.000000   750.000000                      9.000000
# max    1000.000000  1000.000000                     10.000000
#
#        Explains concepts in an understandable way  Use of presentations  \
# count                                 1001.000000           1001.000000
# mean                                     6.081918              5.942058
# std                                      2.597168              1.415853
# min                                      2.000000              4.000000
# ...

# %%
# Moving to Data Cleaning.

# %%
# Droping Unnecessary Column: The column "Unnamed:" 0 is just an index. So, I've decided to drop it.

df.drop(columns=['Unnamed: 0'], inplace=True)

# %%
# Checking Missing Values

df.isnull().sum()
# Out:
# Student ID                                              0
# Well versed with the subject                            0
# Explains concepts in an understandable way              0
# Use of presentations                                    0
# Degree of difficulty of assignments                     0
# Solves doubts willingly                                 0
# Structuring of the course                               0
# Provides support for students going above and beyond    0
# Course recommendation based on relevance                0
# dtype: int64

# %%
# Result: No missing values found.

# %%
# Moving to Overall Satisfaction Analysis.

# %%
#. 1) Creating an Overall Satisfaction Score.

df['Overall_Satisfaction'] = df.iloc[:, 1:].mean(axis=1)
df.head()
# Out:
#    Student ID  Well versed with the subject  \
# 0         340                             5
# 1         253                             6
# 2         680                             7
# 3         806                             9
# 4         632                             8
#
#    Explains concepts in an understandable way  Use of presentations  \
# 0                                           2                     7
# 1                                           5                     8
# 2                                           7                     6
# 3                                           6                     7
# 4                                          10                     8
#
#    Degree of difficulty of assignments  Solves doubts willingly  \
# 0                                    6                        9
# 1                                    6                        2
# 2                                    5                        4
# ...

# %%
# 2) Finding the distribution of Overall Satisfaction.

plt.figure(figsize=(8,5))
plt.hist(df['Overall_Satisfaction'], bins=10)
plt.xlabel("Overall Satisfaction Score")
plt.ylabel("Number of Students")
plt.title("Distribution of Overall Satisfaction")
plt.show()

# %%
# Insight: Most of the satisfaction scores are clustered around the middle point. So, most of the students have moderate satisfaction rate.

# %%
# Moving on to Average Rating per Parameter.

avg_ratings = df.iloc[:, 1:-1].mean().sort_values(ascending=False)
avg_ratings
# Out:
# Well versed with the subject                            7.497502
# Explains concepts in an understandable way              6.081918
# Use of presentations                                    5.942058
# Provides support for students going above and beyond    5.662338
# Structuring of the course                               5.636364
# Course recommendation based on relevance                5.598402
# Solves doubts willingly                                 5.474525
# Degree of difficulty of assignments                     5.430569
# dtype: float64

# %%
# Providing the visualisation for it with Bar Chart.

plt.figure(figsize=(10,6))
avg_ratings.plot(kind='bar')
plt.ylabel("Average Rating")
plt.title("Average Ratings by Feedback Category")
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
# Insight: From the chart, we can see that students have rated the experience of the teacher as the highest among all the categories.
# Other categories have received fairly similar ratings.

# %%
# Moving on to Satisfaction Level Classification.

# %%
# Creating Satisfaction Labels.

def satisfaction_label(score):
    if score >= 7:
        return "Positive"
    elif score >= 4:
        return "Neutral"
    else:
        return "Negative"

df['Satisfaction_Level'] = df['Overall_Satisfaction'].apply(satisfaction_label)

# %%
# Creating Distribution of Satisfaction Levels.

df['Satisfaction_Level'].value_counts()
# Out:
# Satisfaction_Level
# Neutral     860
# Positive    131
# Negative     10
# Name: count, dtype: int64

# %%
# Creating Pie Chart visualization.

df['Satisfaction_Level'].value_counts().plot(
    kind='pie',
    autopct='%1.1f%%',
    figsize=(6,6),
    title="Student Satisfaction Levels"
)
plt.ylabel("")
plt.show()

# %%
# Insight: Most of the students are showing 'Neutral' satisfaction level and signaling a neutral sentiment.

# %%
# Moving on to Correlation Analysis.

plt.figure(figsize=(10,6))
sns.heatmap(df.iloc[:,1:-2].corr(), annot=True, cmap='coolwarm')
plt.title("Correlation Between Feedback Parameters")
plt.show()

# %%
# Insight: There is a strong link between clarity of explaination and course structure.

# %%
# Moving on to Top & Weak Areas Identification.

# %%
# 1) Finding top 3 strengths.

avg_ratings.head(3)
# Out:
# Well versed with the subject                  7.497502
# Explains concepts in an understandable way    6.081918
# Use of presentations                          5.942058
# dtype: float64

# %%
# 2) Finding bottom 3 improvement areas.

avg_ratings.tail(3)
# Out:
# Course recommendation based on relevance    5.598402
# Solves doubts willingly                     5.474525
# Degree of difficulty of assignments         5.430569
# dtype: float64

# %% [markdown]
# ## Key Insights
# - Overall student satisfaction is generally positive.
# - Faculty are strongest in subject knowledge and course relevance.
# - Areas needing improvement include assignment difficulty and student support.
# - Strong correlations exist between teaching clarity and course recommendation.

# %% [markdown]
# ## Recommendations
# - Simplify assignment difficulty or provide better guidance.
# - Increase one-on-one doubt-solving sessions.
# - Improve course structuring for better learning flow.
# - Focus on student support initiatives for advanced learners.
